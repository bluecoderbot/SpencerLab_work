# %%
import numpy as np

# %matplotlib qt
import matplotlib.pyplot as plt

from scipy import ndimage as ndi
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


from skimage.morphology import watershed
from skimage.feature import peak_local_max
from PIL import Image

from skimage.morphology import skeletonize, thin, skeletonize_3d
from skimage.util import invert
from skimage import measure
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk
from skimage import feature
from skimage.filters import roberts, sobel, scharr, prewitt
import seaborn as sns
sns.reset_orig()

from skimage import restoration

from skimage import exposure
from skimage.filters import gaussian

from scipy import ndimage

from time import time

from skimage.color import rgb2gray


from skimage.filters.rank import entropy
import scipy



import networkx as nx
from scipy import interpolate

from skimage.segmentation import random_walker
from skimage.data import binary_blobs
from skimage.exposure import rescale_intensity
import glob

from skimage.morphology import disk
from skimage import io
from skimage.morphology import remove_small_objects

import threading

import tifffile
import csv
# Out:
# /Users/spencerlab/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /Users/spencerlab/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
#blood_vessel = io.imread("/Users/spencerlab/Desktop/final_files/Day_3/#1/Blood_Vessel/Blood_vessel_day_3.tif")
#blood_vessel= blood_vessel!=0

# %%
#bv = io.imread("/Users/spencerlab/Desktop/Temporary_Computational_Folders/Blood_Vessels/Graph_development/bv_substack.tif")
#skel_2d = io.imread("/Users/spencerlab/Desktop/Temporary_Computational_Folders/Blood_Vessels/Graph_development/2d_substack.tif")
skel_3d = io.imread("/Users/spencerlab/Desktop/Temporary_Computational_Folders/Blood_Vessels/Graph_development/3d_crop_substack.tif")

# %%
'/Users/spencerlab/Desktop/Temporary_Computational_Folders/Blood_Vessels/Graph_development/3d_crop_substack.tif'
# Out:
# '/Users/spencerlab/Desktop/Temporary_Computational_Folders/Blood_Vessels/Graph_development/3d_crop_substack.tif'

# %%
skel_3d_pts = np.where(skel_3d!=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
ax.scatter(skel_3d_pts[2], skel_3d_pts[1], skel_3d_pts[0], s=20)

# %%
Z_margin = 10
Y_margin = 20
X_margin = 20


Center_Z = 44
Center_Y = 1404
Center_X = 2537

sub_stack = blood_vessel[Center_Z-Z_margin:Center_Z+Z_margin+1,Center_Y-Y_margin:Center_Y+Y_margin+1, Center_X-X_margin:Center_X+X_margin+1]

# %%
#colors = np.empty((3,3,3), dtype=object)
#colors[pts_f] = 'lawngreen'
#colors[pts_e] = 'yellow'
#colors[pts_c] = 'darkorange'

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.voxels(skel_3d,  edgecolor='k')
# Out:
# {(0, 0, 13): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c26a6fdd8>,
#  (0, 0, 152): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2048>,
#  (0, 1, 12): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2278>,
#  (0, 1, 80): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c24a8>,
#  (0, 1, 85): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c26d8>,
#  (0, 1, 88): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2908>,
#  (0, 1, 134): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2b38>,
#  (0, 1, 152): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2d68>,
#  (0, 2, 12): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1c2f98>,
#  (0, 2, 83): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1d0208>,
#  (0, 2, 84): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1d0438>,
#  (0, 2, 151): <mpl_toolkits.mplot3d.art3d.Poly3DCollection at 0x1c2a1d0668>,
# ...

# %%
z
