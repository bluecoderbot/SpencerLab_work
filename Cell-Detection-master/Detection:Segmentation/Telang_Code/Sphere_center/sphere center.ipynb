# %%
import numpy as np
from copy import deepcopy
import pandas as pd
#get center of cell marked
#cell size over x marked in seperate color
# put every cluster in a csv file
    
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage.morphology import watershed
from skimage.feature import peak_local_max
from PIL import Image
import cv2
from skimage.morphology import skeletonize, thin
from skimage.util import invert
from skimage import measure
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk
from skimage import feature
from skimage.filters import roberts, sobel, scharr, prewitt
import seaborn as sns
sns.reset_orig()
from skimage import measure
from skimage import restoration

from skimage import exposure
from skimage.filters import gaussian

from scipy import ndimage

from time import time

from skimage.color import rgb2gray


from skimage.filters.rank import entropy
import scipy

from skimage import data, filters

import networkx as nx
from scipy import interpolate

from skimage.segmentation import random_walker
from skimage.data import binary_blobs
from skimage.exposure import rescale_intensity
import glob

from skimage.morphology import disk
from skimage import io

import matplotlib.colors
from skimage import data
from skimage.color import rgb2hsv

from mpl_toolkits.mplot3d import axes3d, Axes3D
# Out:
# /Users/spencerlab/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /Users/spencerlab/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
#get theymus edge also
#modify program to have bounds and a try exception for the values outside to be 0

# %%
#bmap = io.imread("D:/chrome download/Blood_vessel_day_3.tif")
bmap = io.imread("ined.tif")
#274
#

# %%
bmap = np.swapaxes(bmap,0,1)
bmap.shape
# Out:
# (822, 2752, 3968)

# %%
data1 = pd.read_csv("newgreen.csv")
data = data1.to_numpy()
data[1]
data = data[:,1:4]

data[:,0]= data[:,0]*3+1
data.shape
# Out:
# (578, 3)

# %%
data[0]
# Out:
# array([   7., 1420., 1837.])

# %%
bmap[3,1420,1837]
# Out:
# 0

# %%
bmap.shape
#z y x
# Out:
# (822, 2752, 3968)

# %%
x=[[[0,0,0,1,0,1,0,0,0,0,0]]]
np.transpose(np.nonzero(x))
idx = np.argwhere(x)
f=0
y=0
z=0
idx[((idx - [z,y,f])**2).sum(1).argmin()]
# Out:
# array([0, 0, 3])

# %%
#76 and 77 arent cells
lmo = io.imread("x7.tif")
#z y x

# %%
for i in range(len(data)):
    try:
        if lmo[int(data[i,0]),int(data[i,1]),int(data[i,2])] ==0:
            print(i)
            data = np.delete(data,obj = i,axis=0)
    except:
        print(i)
        #np.delete(data,obj = i,axis=0)
# Out:
# 263
# 530
# 552
# 569
# 574
# 575
# 576
# 577

# %%
i=50
len(data)
# Out:
# 574

# %%
def calulate(dat, bma)
    data = data
    bmap = bma
    thing=[0,0]
    fails=[0]
    for i in range(len(data)):
        try:
            radius = 3
            array = [[[0]]]
            z_centriod= data[i,0]
            y_centriod= data[i,1]
            x_centriod= data[i,2]
            while(np.sum(array)==0):
                array = (bmap[int(z_centriod-radius):int(z_centriod+radius+1), int(y_centriod-radius):int(y_centriod+radius+1)
                          , int(x_centriod-radius):int(x_centriod+radius+1)] ).copy() 
            #set everything outside the radius to 0

                z0, y0, x0 = int(np.floor(array.shape[0]/2)), \
                int(np.floor(array.shape[1]/2)), int(np.floor(array.shape[2]/2))
                for x in range(x0-radius, x0+radius+1):
                    for y in range(y0-radius, y0+radius+1):
                        for z in range(z0-radius, z0+radius+1):   
                            deb = radius - abs(x0-x) - abs(y0-y) - abs(z0-z) 
                            if (deb)>=0: 
                                array[z,y,x] = array[z,y,x]
                            else:
                                array[z,y,x] = 0
                radius +=2
            # gives indicies of all non zero values in the sphere
            #np.transpose(np.nonzero(x))
            l = np.argwhere(array)
            m=l[((l - [z0,y0,x0])**2).sum(1).argmin()]
            dist = ((m[0]-z0)**2+(m[1]-y0)**2+((m[2]-x0))**2)**.5
            add=[i,dist]
            thing = np.vstack((thing,add))
            print(add)

        except:
            print(i + "errored")
            fails=np.vstack((fails,i))
            pass # doing nothing on exception
# Out:
# 9
# [1, 7.280109889280518]
# [2, 6.4031242374328485]
# [3, 3.605551275463989]
# [4, 7.0710678118654755]
# [5, 6.708203932499369]
# [6, 7.615773105863909]
# [7, 0.0]
# [8, 4.0]
# [9, 3.3166247903554]
# [10, 0.0]
# [11, 3.1622776601683795]
# [12, 1.0]
# [13, 0.0]
# [14, 9.0]
# [15, 10.0]
# [16, 6.708203932499369]
# [17, 3.1622776601683795]
# [18, 1.4142135623730951]
# [19, 3.0]
# [20, 3.0]
# [21, 7.810249675906654]
# [22, 6.0]
# [23, 12.041594578792296]
# [24, 4.0]
# [25, 0.0]
# [26, 10.488088481701515]
# [27, 2.0]
# [28, 0.0]
# [29, 0.0]
# [30, 3.0]
# [31, 17.029386365926403]
# [32, 0.0]
# [33, 13.038404810405298]
# [34, 5.0]
# [35, 3.1622776601683795]
# [36, 2.23606797749979]
# [37, 0.0]
# [38, 3.3166247903554]
# [39, 7.810249675906654]
# [40, 0.0]
# [41, 1.0]
# [42, 2.0]
# [43, 10.04987562112089]
# [44, 7.681145747868608]
# [45, 2.0]
# [46, 2.449489742783178]
# [47, 1.0]
# [48, 5.0990195135927845]
# [49, 0.0]
# [50, 8.94427190999916]
# [51, 5.0990195135927845]
# [52, 3.3166247903554]
# [53, 6.0]
# [54, 0.0]
# [55, 6.708203932499369]
# [56, 6.0]
# [57, 2.0]
# [58, 6.0]
# [59, 6.082762530298219]
# [60, 0.0]
# [61, 12.206555615733702]
# [62, 1.0]
# [63, 13.490737563232042]
# [64, 4.0]
# [65, 10.44030650891055]
# [66, 4.58257569495584]
# [67, 5.385164807134504]
# [68, 5.196152422706632]
# [69, 9.848857801796104]
# [70, 0.0]
# [71, 3.0]
# [72, 2.23606797749979]
# [73, 13.379088160259652]
# [74, 8.306623862918075]
# [75, 10.04987562112089]
# [76, 10.344080432788601]
# [77, 0.0]
# [78, 5.0]
# [79, 1.0]
# [80, 9.486832980505138]
# [81, 4.0]
# [82, 7.0710678118654755]
# [83, 10.04987562112089]
# [84, 5.0]
# [85, 0.0]
# [86, 3.605551275463989]
# [87, 7.280109889280518]
# [88, 3.1622776601683795]
# [89, 7.0710678118654755]
# [90, 0.0]
# [91, 7.0]
# [92, 0.0]
# [93, 0.0]
# [341, 2.0]
# [342, 3.1622776601683795]
# [343, 5.0]
# [344, 3.0]
# [345, 17.0]
# [346, 1.0]
# [347, 1.0]
# [348, 4.123105625617661]
# [349, 12.206555615733702]
# [350, 15.0]
# [351, 0.0]
# [352, 4.0]
# [353, 0.0]
# [354, 13.892443989449804]
# [355, 0.0]
# [356, 0.0]
# [357, 4.123105625617661]
# [358, 7.0]
# [359, 3.1622776601683795]
# [360, 13.038404810405298]
# [361, 6.557438524302]
# [362, 4.0]
# [363, 19.026297590440446]
# [364, 15.0]
# [365, 0.0]
# [366, 1.0]
# [367, 5.0990195135927845]
# [368, 13.0]
# [369, 2.23606797749979]
# [370, 1.0]
# [371, 13.152946437965905]
# [372, 1.4142135623730951]
# [373, 11.0]
# [374, 1.0]
# [375, 3.0]
# [376, 3.7416573867739413]
# [377, 3.605551275463989]
# [378, 9.0]
# [379, 4.123105625617661]
# [380, 3.3166247903554]
# [381, 3.605551275463989]
# [382, 7.681145747868608]
# [383, 18.027756377319946]
# [384, 0.0]
# [385, 0.0]
# [386, 6.324555320336759]
# [387, 1.4142135623730951]
# [388, 4.123105625617661]
# [389, 9.0]
# [390, 7.810249675906654]
# [391, 9.0]
# [392, 0.0]
# [393, 9.0]
# [394, 11.180339887498949]
# [395, 4.358898943540674]
# [396, 1.4142135623730951]
# [397, 0.0]
# [398, 7.280109889280518]
# [399, 3.0]
# [400, 4.0]
# [401, 8.0]
# [402, 8.06225774829855]
# [403, 3.0]
# [404, 0.0]
# [405, 0.0]
# [406, 3.605551275463989]
# [407, 5.196152422706632]
# [408, 6.082762530298219]
# [409, 3.7416573867739413]
# [410, 2.449489742783178]
# [411, 6.4031242374328485]
# [412, 4.242640687119285]
# [413, 13.152946437965905]
# [414, 0.0]
# [415, 2.8284271247461903]
# [416, 2.23606797749979]
# [417, 9.0]
# [418, 12.083045973594572]
# [419, 7.211102550927978]
# [420, 0.0]
# [421, 4.123105625617661]
# [422, 3.1622776601683795]
# [423, 0.0]
# [424, 5.196152422706632]
# [425, 1.0]
# [426, 7.280109889280518]
# [427, 6.082762530298219]
# [428, 13.341664064126334]
# [429, 4.358898943540674]
# [430, 9.0]
# [431, 4.47213595499958]
# [432, 16.522711641858304]
# [433, 6.082762530298219]
# [434, 12.041594578792296]
# [435, 7.14142842854285]
# [436, 0.0]
# [437, 1.4142135623730951]
# [438, 8.831760866327848]
# [439, 0.0]
# [440, 3.0]
# [441, 0.0]
# [442, 5.0]
# [443, 6.708203932499369]
# [444, 5.830951894845301]
# [445, 1.0]
# [446, 1.0]
# [447, 12.0]
# [448, 12.041594578792296]
# [449, 3.7416573867739413]
# [450, 0.0]
# [451, 3.0]
# [452, 5.830951894845301]
# [453, 0.0]
# [454, 14.422205101855956]
# [455, 1.4142135623730951]
# [456, 2.23606797749979]
# [457, 0.0]
# [458, 2.8284271247461903]
# [459, 3.1622776601683795]
# [460, 1.0]
# [461, 3.0]
# [462, 10.04987562112089]
# [463, 1.0]
# [464, 0.0]
# [465, 0.0]
# [466, 0.0]
# [467, 3.3166247903554]
# [468, 3.0]
# [469, 3.0]
# [470, 0.0]
# [471, 10.198039027185569]
# [472, 4.242640687119285]
# [473, 0.0]
# [474, 5.0]
# [475, 3.0]
# [476, 1.0]
# [477, 0.0]
# [478, 0.0]
# [479, 3.0]
# [480, 0.0]
# [481, 5.0]
# [482, 10.44030650891055]
# [483, 9.1104335791443]
# [484, 1.4142135623730951]
# [485, 11.0]
# [486, 2.0]
# [487, 9.899494936611665]
# [488, 0.0]
# [489, 12.0]
# [490, 3.605551275463989]
# [491, 18.0]
# [492, 5.385164807134504]
# [493, 10.344080432788601]
# [494, 0.0]
# [495, 5.0]
# [496, 3.1622776601683795]
# [497, 12.96148139681572]
# [498, 0.0]
# [499, 5.0990195135927845]
# [500, 3.1622776601683795]
# [501, 0.0]
# [502, 3.0]
# [503, 6.082762530298219]
# [504, 7.0]
# [505, 5.0]
# [506, 5.0]
# [507, 0.0]
# [508, 3.1622776601683795]
# [509, 0.0]
# [510, 0.0]
# [511, 4.0]
# [512, 0.0]
# [513, 20.0]
# [514, 0.0]
# [515, 1.4142135623730951]
# [516, 1.0]
# [517, 16.0312195418814]
# [518, 3.0]
# [519, 1.0]
# [520, 2.23606797749979]
# [521, 6.0]
# [522, 0.0]
# [523, 2.0]
# [524, 0.0]
# [525, 3.1622776601683795]
# [526, 0.0]
# [527, 7.0710678118654755]
# [528, 9.219544457292887]
# [529, 1.0]
# [530, 9.0]
# [531, 0.0]
# [532, 6.082762530298219]
# [533, 1.0]
# [534, 13.30413469565007]
# [535, 0.0]
# [536, 5.0]
# [537, 3.0]
# [538, 2.0]
# [539, 8.0]
# [540, 0.0]
# [541, 0.0]
# [542, 12.041594578792296]
# [543, 12.649110640673518]
# [544, 2.23606797749979]
# [545, 1.0]
# [546, 5.385164807134504]
# [547, 4.123105625617661]
# [548, 0.0]
# [549, 1.4142135623730951]
# [550, 3.0]
# [551, 3.0]
# [552, 3.1622776601683795]
# [553, 5.0]
# [554, 3.0]
# [555, 1.4142135623730951]
# [556, 10.246950765959598]
# [557, 8.06225774829855]
# [558, 5.385164807134504]
# [559, 0.0]
# [560, 16.0]
# [561, 4.0]
# [562, 1.0]
# [563, 0.0]
# [564, 3.0]
# [565, 4.123105625617661]
# [566, 10.04987562112089]
# [567, 1.0]
# [568, 0.0]
# [569, 4.58257569495584]
# [570, 10.63014581273465]
# [571, 2.23606797749979]
# [572, 0.0]
# [573, 1.0]

# %%
thing
# Out:
# array([[  0.        ,   0.        ],
#        [  1.        ,   7.28010989],
#        [  2.        ,   6.40312424],
#        ...,
#        [571.        ,   2.23606798],
#        [572.        ,   0.        ],
#        [573.        ,   1.        ]])

# %%
len(fails)
# Out:
# 2

# %%
thing=np.delete(thing,obj=0,axis=0)

# %%
# Out:
# array([], shape=(0, 0), dtype=int64)

# %%
pd.DataFrame(thing).to_csv("finals.csv")
